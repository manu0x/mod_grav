# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
    
def plot_bgrid_S3_z0(n=4):
    data = np.genfromtxt("s3_z0_bgrid.txt",delimiter="\t")
    grid_n = int(data.shape[0]/n)
    list_om = [r'$\Omega_{m0}=0.1$',r'$\Omega_{m0}=0.2$',r'$\Omega_{m0}=0.3$',r'$\Omega_{m0}=0.4$']
    list_symb = ["b*-","r.-","g--","k-"]
    list_ms = [5.5 for i in range(len(list_om))]
    print("grid_n is ",grid_n)
    om = data[:,0]
    b1= data[:,1]
    s3 = data[:,2]
    fig=plt.figure(figsize=(12.0,9.5), dpi=80)
    #fig.suptitle('Overdensity at turn around', fontsize=14, fontweight='bold')
    gs = gridspec.GridSpec(1, 1)
    ax1 = plt.subplot(gs[0, 0])
    ax1.set_ylabel(r"$S_3(z=0)$",fontsize=40)
    ax1.set_xlabel(r"$B_1$",fontsize=40)
    #ax1.set_xscale('log')
    ax1.tick_params(axis='both', which='major',labelsize=13)
    
    i=0
    for omval in list_om:
        ax1.plot(b1[i*grid_n:(i+1)*grid_n],s3[i*grid_n:(i+1)*grid_n],list_symb[i],ms=list_ms[i],label=list_om[i])
        i = i+1
    
    
    ax1.legend(loc='best',frameon=False, fontsize=20)

    fig.savefig("bgrid_S3.pdf",dpi=fig.dpi,bbox_inches='tight')
    
    return om,b1,s3

# %%
    
def plot_omgrid_S3_z0(n=5):
    data = np.genfromtxt("s3_z0_omgrid.txt",delimiter="\t")
    grid_n = int(data.shape[0]/n)
    list_b1 = [r'$B_1=0.0$',r'$B_1=0.2$',r'$B_1=0.5$',r'$B_1=0.9$',r'$B_1=1.0$']
    list_symb = ["b*-","r.-","g--","m*-","k*"]
    list_ms = [5.5 for i in range(len(list_b1))]
    print("grid_n is ",grid_n)
    om = data[:,0]
    b1= data[:,1]
    s3 = data[:,2]
    fig=plt.figure(figsize=(12.0,9.5), dpi=80)
    #fig.suptitle('Overdensity at turn around', fontsize=14, fontweight='bold')
    gs = gridspec.GridSpec(1, 1)
    ax1 = plt.subplot(gs[0, 0])
    ax1.set_ylabel(r"$S_3(z=0)$",fontsize=40)
    ax1.set_xlabel(r"$\Omega_{dm0}$",fontsize=40)
    #ax1.set_xscale('log')
    ax1.tick_params(axis='both', which='major',labelsize=13)
    
    i=0
    for b1val in list_b1:
        ax1.plot(om[i*grid_n:(i+1)*grid_n],s3[i*grid_n:(i+1)*grid_n],list_symb[i],ms=list_ms[i],label=list_b1[i])
        i = i+1
    
   # ax1.axhline(y=4.857, color='m', linestyle='-',label="EDS")
    ax1.legend(loc='best',frameon=False, fontsize=20)

    fig.savefig("omgrid_S3.pdf",dpi=fig.dpi,bbox_inches='tight')
    
    return om,b1,s3

# %%
om,b1,s3=plot_omgrid_S3_z0()
# Out:
# grid_n is  200

# %%
om2,b12,s32=plot_bgrid_S3_z0()
# Out:
# grid_n is  200

# %%
om = np.genfromtxt("omv.txt")
b1 = np.genfromtxt("b1v.txt")
s3 = np.genfromtxt("s30v.txt")


fig=plt.figure(figsize=(8.0,6.0), dpi=80)
axwc = plt.subplot()
wc = axwc.contourf(b1,om,s3)
axwc.plot(1.69038,0.2791,"ro",label="fit")
axwc.set_xlim([0.0, 2])
axwc.set_xlabel("$B_1$",fontsize=30)
axwc.set_ylabel("$\Omega_{m0}$",fontsize=30)
fig.colorbar(wc)
axwc.set_title("$S_3(z=0)$ ",fontsize=30)
fig.savefig("s3z0_contour.pdf",dpi=fig.dpi,bbox_inches='tight')

# %%
om = np.genfromtxt("omv.txt")
b1 = np.genfromtxt("b1v.txt")
s3 = np.genfromtxt("s30v.txt")
s3diffperc = 100.0*np.abs(s3 - 4.8645416)/4.8645416

fig=plt.figure(figsize=(8.0,6.0), dpi=80)
axwc = plt.subplot()
axwc.set_xlim([0.0, 2.0])
wc = axwc.contourf(b1,om,s3diffperc)
axwc.plot(1.69038,0.2791,"ro",label="fit")
axwc.set_xlabel("$B_1$",fontsize=30)
axwc.set_ylabel("$\Omega_{m0}$",fontsize=30)
fig.colorbar(wc)
axwc.set_title("$\%\Delta(S_3(z=0))$",fontsize=30)
fig.savefig("s3z0_diff_contour.pdf",dpi=fig.dpi,bbox_inches='tight')

# %%
plt.plot(s3.flatten())

# %%
s3.shape
# Out:
# (200, 201)

# %%
wcnt = np.genfromtxt("w_cnt.txt")
qcnt = np.genfromtxt("q_cnt.txt")
wdiffcnt = np.genfromtxt("wdiff_cnt.txt")
b1cnt = np.genfromtxt("b1_cnt.txt")
omcnt = np.genfromtxt("om_cnt.txt")
wcnt.shape
# Out:
# (301, 301)

# %%
fig=plt.figure(figsize=(8.0,6.0), dpi=80)
axwc = plt.subplot()
wc = axwc.contourf(b1cnt,omcnt,wdiffcnt,[0,5,10,30,50])
axwc.set_xlabel("$B_1$",fontsize=30)
axwc.set_ylabel("$\Omega_{m0}$",fontsize=30)
fig.colorbar(wc)
axwc.set_title("% deviation of w(z=0) ",fontsize=30)
fig.savefig("wdiff_contour.pdf",dpi=fig.dpi,bbox_inches='tight')

# %%
fig=plt.figure(figsize=(8.0,6.0), dpi=80)
axwc = plt.subplot()
wc = axwc.contourf(b1cnt,omcnt,wcnt,[-8.0,-5.0,-3.0,-2.5,-2.0,-1.0,0.0])
axwc.set_xlabel("$B_1$",fontsize=30)
axwc.set_ylabel("$\Omega_{m0}$",fontsize=30)
fig.colorbar(wc)
axwc.set_title("w(z=0) ",fontsize=30)
fig.savefig("w_contour.pdf",dpi=fig.dpi,bbox_inches='tight')

# %%
fig=plt.figure(figsize=(8.0,6.0), dpi=80)
axwc = plt.subplot()
wc = axwc.contourf(b1cnt,omcnt,qcnt,[-1.0,0.0,1.0,2])
axwc.set_xlabel("$B_1$",fontsize=30)
axwc.set_ylabel("$\Omega_{m0}$",fontsize=30)
fig.colorbar(wc)
axwc.set_title("q(z=0) ",fontsize=30)
fmt = {}
strs = ['acc','0','1','2']
for l, s in zip(wc.levels, strs):
    fmt[l] = s
axwc.clabel(wc, wc.levels[::2],inline=True, fmt=fmt, fontsize=10)
#axwc.legend(loc="best")
fig.savefig("q_contour.pdf",dpi=fig.dpi,bbox_inches='tight')
# Out:
# No handles with labels found to put in legend.

# %%
wcnt = np.genfromtxt("w_cnt.txt")
qcnt = np.genfromtxt("q_cnt.txt")
wdiffcnt = np.genfromtxt("wdiff_cnt.txt")
b1cnt = np.genfromtxt("b1_cnt.txt")
omcnt = np.genfromtxt("om_cnt.txt")

# %%
wcnt = []
qcnt = []
wdiffcnt = []
b1cnt = []
omcnt = []
wz_lst = [0,0.5,1,2]

# %%
for w in wz_lst:
    wcnt_name = "w_cnt_z_"+str(w)+".txt"
    wcnt.append(np.genfromtxt(wcnt_name))
    
    qcnt_name = "q_cnt_z_"+str(w)+".txt"
    qcnt.append(np.genfromtxt(qcnt_name))
    
    wdiffcnt_name = "wdiff_cnt_z_"+str(w)+".txt"
    wdiffcnt.append(np.genfromtxt(wdiffcnt_name))
    
    b1cnt_name = "b1_cnt_z_"+str(w)+".txt"
    b1cnt.append(np.genfromtxt(b1cnt_name))
    
    omcnt_name = "om_cnt_z_"+str(w)+".txt"
    omcnt.append(np.genfromtxt(omcnt_name))
    
fig=plt.figure(figsize=(8.0,8.0), dpi=80)
gs = gridspec.GridSpec(2, 2,hspace=0.4)
 
    
for i in range(2):
    for j in range(2):
        print(i,j)
        k = i*2+j
        print("w(z="+str(wz_lst[k])+")")
        axwc = plt.subplot(gs[i, j])
        wc = axwc.contourf(b1cnt[k],omcnt[k],wcnt[k],[-8.0,-2.0,-1.0,0.0,1.0,5.0,10],cmap=plt.cm.viridis)
        if i==1:
            axwc.set_xlabel("$B_1$",fontsize=30)
        if j==0:
            axwc.set_ylabel("$\Omega_{m0}$",fontsize=30)
        fig.colorbar(wc)
        axwc.set_title("w(z="+str(wz_lst[k])+")",fontsize=30)
        
        
fig.savefig("w_contour_z.pdf",dpi=fig.dpi,bbox_inches='tight')
# Out:
# 0 0
# w(z=0)
# 0 1
# w(z=0.5)
# 1 0
# w(z=1)
# 1 1
# w(z=2)
