# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
word_om = [0.3]
word_b1 = [0.0,0.2,0.5,1.0,2.0,-0.2,-0.5,-1.0,-2.0]


list_symb = ["b--","r-","g--","k--","c.","m--","b.","r-","g-"]
list_ms = [0.5 for i in range(len(word_b1))]
print(list_ms,len(list_symb),len(list_ms))



data_b1 = []
data_b1_fs8 = []
list_tit = []
list_tit_fs8 = []

for b1 in word_b1:
    name = "delta_bimetric_om_0.3_B1_"+str(b1)+".txt"
    name_fs8 = "delta_bimetric_om_0.3_B1_"+str(b1)+"_fs8.txt"
    data_b1.append( np.genfromtxt(name,delimiter="\t"))
    data_b1_fs8.append( np.genfromtxt(name_fs8,delimiter="\t"))
    
    list_tit.append("B1="+str(b1))
    list_tit_fs8.append("B1="+str(b1))
    print(name)
    
list_mod = data_b1
list_mod_fs8 = data_b1_fs8
list_mod_h = data_b1[:5]
# Out:
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5] 9 9
# delta_bimetric_om_0.3_B1_0.0.txt
# delta_bimetric_om_0.3_B1_0.2.txt
# delta_bimetric_om_0.3_B1_0.5.txt
# delta_bimetric_om_0.3_B1_1.0.txt
# delta_bimetric_om_0.3_B1_2.0.txt
# delta_bimetric_om_0.3_B1_-0.2.txt
# delta_bimetric_om_0.3_B1_-0.5.txt
# delta_bimetric_om_0.3_B1_-1.0.txt
# delta_bimetric_om_0.3_B1_-2.0.txt

# %%
fs_8_data = np.genfromtxt("data.txt",delimiter="\t")

# %%
fs_8_data.shape
# Out:
# (18, 4)

# %%
def plot_linear(c = 4):
    fig=plt.figure(figsize=(12.0,9.5), dpi=80)
    #fig.suptitle('Overdensity at turn around', fontsize=14, fontweight='bold')
    gs = gridspec.GridSpec(1, 1)
    ax1 = plt.subplot(gs[0, 0])
    ax1.set_ylabel(r"$\frac{\delta_1}{a}$",fontsize=40)
    ax1.set_xlabel("$a$",fontsize=40)
    ax1.set_xscale('log')
    ax1.tick_params(axis='both', which='major',labelsize=13)
    ax1.set_xlim([0.002, 1.0])
    
    i=0
    for mod in list_mod_h:
        ax1.plot(mod[:,0],mod[:,c],list_symb[i],ms=list_ms[i],label=list_tit[i])
        i = i+1
    
    
    ax1.legend(loc='best',frameon=False, fontsize=20)

    fig.savefig("linear.pdf",dpi=fig.dpi,bbox_inches='tight')
    
    
def plot_2nd(c =7):
    fig=plt.figure(figsize=(12.0,9.5), dpi=80)
    #fig.suptitle('Overdensity at turn around', fontsize=14, fontweight='bold')
    gs = gridspec.GridSpec(1, 1)
    ax1 = plt.subplot(gs[0, 0])
    ax1.set_ylabel(r"$\frac{\delta_2}{{\delta_2}_{ini}}$",fontsize=40)
    ax1.set_xlabel("$a$",fontsize=40)
    ax1.set_xscale('log')
    ax1.set_yscale('log')
    ax1.tick_params(axis='both', which='major',labelsize=13)
    
    i=0
    for mod in list_mod:
        ax1.plot(mod[:,0],mod[:,c],list_symb[i],ms=list_ms[i],label=list_tit[i])
        i = i+1
    
    
    ax1.legend(loc='best',frameon=False, fontsize=20)

    fig.savefig("second_ord.pdf",dpi=fig.dpi,bbox_inches='tight')

def plot_S3(c=9):
    fig=plt.figure(figsize=(12.0,9.5), dpi=80)
    #fig.suptitle('Overdensity at turn around', fontsize=14, fontweight='bold')
    gs = gridspec.GridSpec(2, 1,hspace=0.01)
    
    ax1 = plt.subplot(gs[0, 0])
    ax1.set_ylabel(r"$S_3$",fontsize=40)
    #ax1.set_xlabel("$a$",fontsize=40)
    ax1.set_xscale('log')
    ax1.tick_params(axis='both', which='major',labelsize=13)
    ax1.set_xlim([0.001, 1.0])
    
    ax2 = plt.subplot(gs[1, 0])
    ax2.set_ylabel(r"$\Delta S_3$ %",fontsize=40)
    ax2.set_xlabel("$a$",fontsize=40)
    ax2.set_xscale('log')
    ax2.tick_params(axis='both', which='major',labelsize=13)
    ax2.set_xlim([0.001, 1.0])
    
    i=0
    for mod in list_mod:
        ax1.plot(mod[:,0],mod[:,c],list_symb[i],ms=list_ms[i],label=list_tit[i])
        ax2.plot(mod[:,0],100.0*np.abs(mod[:,c]-list_mod[0][:,c])/list_mod[0][:,c],list_symb[i],ms=list_ms[i],label=list_tit[i])
        i = i+1
    
    
    ax1.legend(loc='best',frameon=False, fontsize=10)
    ax2.legend(loc='best',frameon=False, fontsize=10)
    
    
    

    fig.savefig("S3.pdf",dpi=fig.dpi,bbox_inches='tight')
    
def plot_fs8(c=1):
    fig=plt.figure(figsize=(12.0,9.5), dpi=80)
    #fig.suptitle('Overdensity at turn around', fontsize=14, fontweight='bold')
    gs = gridspec.GridSpec(1, 1)
    ax1 = plt.subplot(gs[0, 0])
    ax1.set_ylabel("$f\sigma_8$",fontsize=40)
    ax1.set_xlabel("$z$",fontsize=40)
    #ax1.set_xscale('log')
    ax1.tick_params(axis='both', which='major',labelsize=13)
    
    
    i=0
    for mod in list_mod_fs8:
        #s = np.argsort(mod[:,0])
        ax1.plot(mod[:,0],mod[:,c],list_symb[i],ms=list_ms[i],label=list_tit_fs8[i])
        i = i+1
    #ax1.errorbar(fs_8_data[:,0],fs_8_data[:,1],yerr =np.stack((fs_8_data[:,2],fs_8_data[:,3]),axis=0), fmt='*',label = "data fs8")
    ax1.errorbar(fs_8_data[:,0],fs_8_data[:,1],yerr =fs_8_data[:,2], fmt='*',label = "data fs8")
    
    ax1.legend(loc='upper right',frameon=False, fontsize=20)

    fig.savefig("fs8.pdf",dpi=fig.dpi,bbox_inches='tight')
    
def plot_lcdm_S3(c=9):
    fig=plt.figure(figsize=(12.0,9.5), dpi=80)
    #fig.suptitle('Overdensity at turn around', fontsize=14, fontweight='bold')
    gs = gridspec.GridSpec(1, 1)
    ax1 = plt.subplot(gs[0, 0])
    ax1.set_ylabel(r"$S_3$",fontsize=40)
    ax1.set_xlabel("$a$",fontsize=40)
    ax1.set_xscale('log')
    ax1.tick_params(axis='both', which='major',labelsize=13)
    
    i=0
    for mod in list_lcdm_mod:
        ax1.plot(mod[:,0],mod[:,c],list_symb[i],ms=list_ms[i],label=list_lcdm_tit[i])
        i = i+1
    
    
    ax1.legend(loc='best',frameon=False, fontsize=20)

    fig.savefig("lcdm_S3.pdf",dpi=fig.dpi,bbox_inches='tight')

# %%
plot_linear()

# %%
plot_fs8()

# %%
plot_2nd()

# %%
plot_S3()

# %%
plot_lcdm_S3()

# %%
    fig=plt.figure(figsize=(12.0,9.5), dpi=80)
    #fig.suptitle('Overdensity at turn around', fontsize=14, fontweight='bold')
    gs = gridspec.GridSpec(2, 1,hspace=0.01)
    
    ax1 = plt.subplot(gs[0, 0])
    ax1.set_ylabel(r"$S_3$",fontsize=40)
    #ax1.set_xlabel("$a$",fontsize=40)
    ax1.set_xscale('log')
    ax1.tick_params(axis='both', which='major',labelsize=13)
    ax1.set_xlim([0.001, 1.0])
    
    ax2 = plt.subplot(gs[1, 0])
    ax2.set_ylabel(r"$\Delta S_3$ %",fontsize=40)
    ax2.set_xlabel("$a$",fontsize=40)
    ax2.set_xscale('log')
    ax2.tick_params(axis='both', which='major',labelsize=13)
    ax2.set_xlim([0.001, 1.0])
    
    i=0
    for mod in list_mod:
        ax1.plot(mod[:,0],mod[:,c],list_symb[i],ms=list_ms[i],label=list_tit[i])
        ax2.plot(mod[:,0],100.0*np.abs(mod[:,c]-list_mod[0][:,c])/list_mod[0][:,c],list_symb[i],ms=list_ms[i],label=list_tit[i])
        i = i+1
    
    
    ax1.legend(loc='best',frameon=False, fontsize=10)
    ax2.legend(loc='best',frameon=False, fontsize=10)
    
    
    

    fig.savefig("S3.pdf",dpi=fig.dpi,bbox_inches='tight')
